# %% [markdown]
# # SONAR Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data/sonar.csv', header=None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
# Label Encoder - converting categorical to numeric

from sklearn.preprocessing import LabelEncoder

df['Label'] = LabelEncoder().fit_transform(df.iloc[:,-1])

# %%
# Droping the 60th Column
df = df.drop(df.columns[-2], axis=1)

# %%
df.head()
# Out:
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#         9  ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  Label
# 0  0.0090  0.0032      1
# 1  0.0052  0.0044      1
# ...

# %%
df.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                 6           7           8           9  ...          51  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.013420
# ...

# %%
df.skew()
# Out:
# 0        2.131088
# 1        2.155644
# 2        2.652518
# 3        3.401697
# 4        2.018141
#            ...
# 56       1.653090
# 57       2.098330
# 58       1.737506
# 59       2.775754
# Label    0.135903
# Length: 61, dtype: float64

# %%
for i in df.columns:
    if df.skew().loc[i]> 0.6:
        df[i] = np.sqrt(df[i])

# %%
df.skew()
# Out:
# 0        1.014296
# 1        0.757933
# 2        0.909984
# 3        1.136996
# 4        0.691256
#            ...
# 56       0.681551
# 57       0.803090
# 58       0.616000
# 59       0.986014
# Label    0.135903
# Length: 61, dtype: float64

# %%
from scipy.stats import zscore

z_score = abs(zscore(df))
print(df.shape)
df_final = df.loc[(z_score <3).all(axis=1)]
print(df_final.shape)
# Out:
# (208, 61)
# (189, 61)

# %%
x = df_final.iloc[:, :-1]
y = df_final.iloc[:, -1]

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

xt = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

max_acc_scr = 0
for r_st in range(50, 62):
    x_train, x_test, y_train, y_test = train_test_split(xt, y, test_size = 0.2, random_state = r_st)
    reg = LogisticRegression()
    reg.fit(x_train, y_train)
    y_pred = reg.predict(x_test)
    
    acc_scr = accuracy_score(y_test, y_pred)
    
    if max_acc_scr < acc_scr:
        max_acc_scr = acc_scr
        final_r_st = r_st
print('Max accuracy_score %s according to random state : %s' %(max_acc_scr, r_st))
# Out:
# Max accuracy_score 0.9210526315789473 according to random state : 61

# %%
from sklearn.model_selection import cross_val_score

print('Mean: %s' % cross_val_score(LogisticRegression(), xt, y, cv=10, scoring='accuracy').mean())
# Out:
# Mean: 0.6991228070175438

# %%
x_train, x_test, y_train, y_test = train_test_split(xt, y, test_size = 0.2, random_state = 61)
lg = LogisticRegression()
lg.fit(x_train, y_train)
y_pred = reg.predict(x_test)
acc_scr = accuracy_score(y_test, y_pred)

# %%
print('Confusion Matrix : \n', confusion_matrix(y_test, y_pred))
print('\nClassification Report : \n', classification_report(y_test, y_pred))
# Out:
# Confusion Matrix :
#  [[19  2]
#  [ 1 16]]
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.95      0.90      0.93        21
#            1       0.89      0.94      0.91        17
#
#     accuracy                           0.92        38
#    macro avg       0.92      0.92      0.92        38
# weighted avg       0.92      0.92      0.92        38

# %%
import joblib

joblib.dump(lg, 'lr_sonar.pkl')
# Out:
# ['lr_sonar.pkl']
